# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import time as dt

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/andrealynnbaker/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache

# %%
url = 'https://redplanetscience.com/'
browser.visit(url)

# %%
html = browser.html

# %%
soup = bs(html, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
#   <link href="css/font.css" rel="stylesheet" type="text/css"/>
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
#   <title>
#    News - Mars Exploration Program
#   </title>
#  </head>
#  <body>
#   <div class="col-md-12">
#    <div class="row">
#     <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#      <div class="container-fluid">
#       <a class="navbar-brand" href="#">
# ...

# %%
results = soup.find_all('div', class_='content_title')

results
# Out:
# [<div class="content_title">NASA Invites Students to Name Mars 2020 Rover</div>,
#  <div class="content_title">My Culture, My Voice</div>,
#  <div class="content_title">The Detective Aboard NASA's Perseverance Rover</div>,
#  <div class="content_title">Mars Scientists Investigate Ancient Life in Australia</div>,
#  <div class="content_title">NASA Perseverance Mars Rover Scientists Train in the Nevada Desert</div>,
#  <div class="content_title">NASA's Mars Helicopter Attached to Mars 2020 Rover </div>,
#  <div class="content_title">NASA's Curiosity Rover Finds an Ancient Oasis on Mars</div>,
#  <div class="content_title">NASA's Mars 2020 Rover Tests Descent-Stage Separation</div>,
#  <div class="content_title">NASA's Ingenuity Mars Helicopter Recharges Its Batteries in Flight</div>,
#  <div class="content_title">Independent Review Indicates NASA Prepared for Mars Sample Return Campaign</div>,
#  <div class="content_title">Two of a Space Kind: Apollo 12 and Mars 2020</div>,
# ...

# %%
#news_title = "NASA's Perseverance Rover 100 Days Out"

# news_p = "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."

# %%
news_title = results[0].text

news_title
# Out:
# 'NASA Invites Students to Name Mars 2020 Rover'

# %%
results = soup.find_all('div', class_='article_teaser_body')
results
# Out:
# [<div class="article_teaser_body">Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.</div>,
#  <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>,
#  <div class="article_teaser_body">An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.</div>,
#  <div class="article_teaser_body">Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. </div>,
#  <div class="article_teaser_body">Team members searched for signs of ancient microscopic life there, just as NASA's latest rover will on the Red Planet next year.</div>,
# ...

# %%
new_p = results[0].text
new_p
# Out:
# "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."

# %%
url = "https://spaceimages-mars.com/"
browser.visit(url)

# %%
html = browser.html

# %%
soup = bs(html, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <html class="">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" rel="stylesheet"/>
#   <!-- <link rel="stylesheet" type="text/css" href="css/font.css"> -->
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Space Image
#   </title>
#   <style type="text/css">
#    .fancybox-margin{margin-right:0px;}
#   </style>
#  </head>
#  <body>
#   <div class="header">
#    <nav class="navbar navbar-expand-lg">
#     <a class="navbar-brand" href="#">
#      <img id="logo" src="image/nasa.png"/>
#      <span class="logo">
#       Jet Propulsion Laboratory
#      </span>
#      <span class="logo1">
#       California Institute of Technology
#      </span>
#     </a>
# ...

# %%
results = soup.find_all('a', class_='fancybox-thumbs')

#image_container = results.nextSibling.nextSibling
# image_container
# image_tag = browser.find_by_text('FULL IMAGE')

# print(len(image_tag))
# for images_tag in image_tag:
#     print(images_tag)
    
#(results[1].click('FULL IMAGE'))


# for result in results:
#     print(result)

# print(soup.prettify())
browser.results.find_by_partial_text('button').click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_80537/1465381718.py in <module>
#      16
#      17 # print(soup.prettify())
# ---> 18 browser.results.find_by_partial_text('button').click()
#
# AttributeError: 'WebDriver' object has no attribute 'results'

# %%
url = "https://spaceimages-mars.com"
browser.visit(url)


    
html = browser.html
soup = bs(html, 'html.parser')

results = soup.find_all('button', class_='btn btn-outline-light')

for result in results:
    print(result)
        
src = src.find('jpg')
#         link = book.find('a')
        
#         title = link['title']
#         href = link ['href']
        
#         print('-'*50)
#         print(results)
#         print("https://spaceimages-mars.com")
        
    #browser.links.find_by_partial_text('headerimage fade-in').click()
# Out:
# <button class="btn btn-outline-light"> FULL IMAGE</button>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_80537/2339508649.py in <module>
#      12     print(result)
#      13
# ---> 14 src = src.find('jpg')
#      15 #         link = book.find('a')
#      16
#
# NameError: name 'src' is not defined
